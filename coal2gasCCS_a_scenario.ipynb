# %%
from Electricity_Imports_Analysis import *
# Out:
# ...
# /Users/Hennessy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Index(['Unnamed: 0', 'STATE', 'Plant.Code', 'OP_DATE_TIME', 'Total.NOx.tons',
#        'Total.SO2.tons', 'Total.Gen.MWh', 'Total.CO2.tons', 'TZ', 'CHPFLAG',
#        'ELCALLOC'],
#       dtype='object')

# %%
BAs_sorted = sort_BAs()
#results_imports, results_self, errors_imports, errors_self = run_imports_and_self(BAs_sorted["BACODE"], "isrm","all","L", True, True, False, False, False, results_imports_coal, results_self_coal)
results_imports_a_coal2gasCCS, results_self_a_coal2gasCCS, errors_imports_a_coal2gasCCS, errors_self_a_coal2gasCCS = run_imports_and_self(BAs_sorted["BACODE"], "apsca_q0","all","LK", True, True, False, False, False, True, [], [])
results_imports_a_K_coal2gasCCS = {ba: results_imports_a_coal2gasCCS[ba][0] for ba in results_imports_a_coal2gasCCS}
results_imports_a_L_coal2gasCCS = {ba: results_imports_a_coal2gasCCS[ba][1] for ba in results_imports_a_coal2gasCCS}
results_self_a_K_coal2gasCCS = {ba: results_self_a_coal2gasCCS[ba][0] for ba in results_self_a_coal2gasCCS}
results_self_a_L_coal2gasCCS = {ba: results_self_a_coal2gasCCS[ba][1] for ba in results_self_a_coal2gasCCS}
# Out:
# /Users/Hennessy/Desktop/IMSR/Electricity_Imports_Analysis.py:992: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   start_time_imports = pd.datetime.now()
# HECOCEA
# CEA import
# HECO import AMPL
# AMPL import apsca_q0 apsca_q0  apsca_q0 all LK
# PGE
# PGE import apsca_q0 all LK
# all LK
# all LK
# BANC
# BANC import apsca_q0SCLTPWR
# TPWR
# SCL import apsca_q0 all LK
#  import  apsca_q0 PSEIall LK
# PACW
# PACW importall LK
#
# PSEI import apsca_q0 all LK
#  apsca_q0 all LK
# BPAT
# BPAT
# BPATBPAT
#
# AVA
# BPAT
# BPAT
# CHPD
# PSEI
# CISO
# PSEI
# PACW
# GCPD
# SCL
# got geometry
# apsca_q0
# got geometry
# apsca_q0CISO
#
# got geometry
# apsca_q0
# TIDClation Running (15 seconds)
# TPWRlation Running (34 seconds)               simulation Running (13 seconds)               simulation Running (41 seconds)               simulation Running (33 seconds)
# ...

# %%
len(results_imports_a_coal2gasCCS)
# Out:
# 66

# %%
import pickle
   
with open("results_self_coal2gasCCS_a_k",'wb') as f:
    pickle.dump(results_self_a_K_coal2gasCCS, f)
with open("results_imports_coal2gasCCS_a_k",'wb') as f:
    pickle.dump(results_imports_a_K_coal2gasCCS, f)
with open("results_self_coal2gasCCS_a_l",'wb') as f:
    pickle.dump(results_self_a_L_coal2gasCCS, f)
with open("results_imports_coal2gasCCS_a_l",'wb') as f:
    pickle.dump(results_imports_a_L_coal2gasCCS, f)
