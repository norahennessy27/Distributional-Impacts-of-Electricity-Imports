# %%
# %load_ext autoreload
# %autoreload 2
from Electricity_Imports_Analysis import *
# Out:
# ...
# /Users/Hennessy/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# Index(['Unnamed: 0', 'STATE', 'Plant.Code', 'OP_DATE_TIME', 'Total.NOx.tons',
#        'Total.SO2.tons', 'Total.Gen.MWh', 'Total.CO2.tons', 'TZ', 'CHPFLAG',
#        'ELCALLOC'],
#       dtype='object')

# %%
#DOWNLOAD RESULTS
# import pickle
# with open("results_self_i_k",'wb') as f:
#     pickle.dump(results_self_i_K, f)
# with open("results_imports_i_k",'wb') as f:
#     pickle.dump(results_imports_i_K, f)
# with open("results_self_i_l",'wb') as f:
#     pickle.dump(results_self_i_L, f)
# with open("results_imports_i_l",'wb') as f:
#     pickle.dump(results_imports_i_L, f)
    
# with open("results_self_a_k",'wb') as f:
#     pickle.dump(results_self_a_K, f)
# with open("results_imports_a_k",'wb') as f:
#     pickle.dump(results_imports_a_K, f)
# with open("results_self_a_l",'wb') as f:
#     pickle.dump(results_self_a_L, f)
# with open("results_imports_a_l",'wb') as f:
#     pickle.dump(results_imports_a_L, f)

# %%
# import pickle
# with open("results_self_gas_i_k",'wb') as f:
#     pickle.dump(results_self_i_K_gas, f)
# with open("results_imports_gas_i_k",'wb') as f:
#     pickle.dump(results_imports_i_K_gas, f)
# with open("results_self_gas_i_l",'wb') as f:
#     pickle.dump(results_self_i_L_gas, f)
# with open("results_imports_gas_i_l",'wb') as f:
#     pickle.dump(results_imports_i_L_gas, f)
    
# with open("results_self_gas_a_k",'wb') as f:
#     pickle.dump(results_self_a_K_gas, f)
# with open("results_imports_gas_a_k",'wb') as f:
#     pickle.dump(results_imports_a_K_gas, f)
# with open("results_self_gas_a_l",'wb') as f:
#     pickle.dump(results_self_a_L_gas, f)
# with open("results_imports_gas_a_l",'wb') as f:
#     pickle.dump(results_imports_a_L_gas, f)

# %%
# #LOAD RESULTS
import pickle

# with open("results_self_i_k",'rb') as f:
#     results_self_i_K = pickle.load(f)
# with open("results_imports_i_k",'rb') as f:
#     results_imports_i_K = pickle.load(f)
# with open("results_self_i_l",'rb') as f:
#     results_self_i_L = pickle.load(f)
# with open("results_imports_i_l",'rb') as f:
#     results_imports_i_L = pickle.load(f)
    
# with open("results_self_a_k",'rb') as f:
#     results_self_a_K = pickle.load(f)
# with open("results_imports_a_k",'rb') as f:
#     results_imports_a_K = pickle.load(f)
# with open("results_self_a_l",'rb') as f:
#     results_self_a_L = pickle.load(f)
# with open("results_imports_a_l",'rb') as f:
#     results_imports_a_L = pickle.load(f)
    
# results_imports_i = {ba: (results_imports_i_K[ba],results_imports_i_L[ba]) for ba in results_imports_i_K}
# results_self_i = {ba: (results_self_i_K[ba],results_self_i_L[ba]) for ba in results_self_i_K}
# results_imports_a = {ba: (results_imports_a_K[ba],results_imports_a_L[ba]) for ba in results_imports_a_K}
# results_self_a = {ba: (results_self_a_K[ba],results_self_a_L[ba]) for ba in results_self_a_K}

# %%
#LOAD RESULTS
# with open("results_self_gas_i_k",'rb') as f:
#     results_self_i_K_gas = pickle.load(f)
# with open("results_imports_gas_i_k",'rb') as f:
#     results_imports_i_K_gas = pickle.load(f)
# with open("results_self_gas_i_l",'rb') as f:
#     results_self_i_L_gas = pickle.load(f)
# with open("results_imports_gas_i_l",'rb') as f:
#     results_imports_i_L_gas = pickle.load(f)
    
# with open("results_self_gas_a_k",'rb') as f:
#     results_self_a_K_gas = pickle.load(f)
# with open("results_imports_gas_a_k",'rb') as f:
#     results_imports_a_K_gas = pickle.load(f)
# with open("results_self_gas_a_l",'rb') as f:
#     results_self_a_L_gas = pickle.load(f)
# with open("results_imports_gas_a_l",'rb') as f:
#     results_imports_a_L_gas = pickle.load(f)
    
# results_imports_i_gas = {ba: (results_imports_i_K_gas[ba],results_imports_i_L_gas[ba]) for ba in results_imports_i_K_gas}
# results_self_i_gas = {ba: (results_self_i_K_gas[ba],results_self_i_L_gas[ba]) for ba in results_self_i_K_gas}
# results_imports_a_gas = {ba: (results_imports_a_K_gas[ba],results_imports_a_L_gas[ba]) for ba in results_imports_a_K_gas}
# results_self_a_gas = {ba: (results_self_a_K_gas[ba],results_self_a_L_gas[ba]) for ba in results_self_a_K_gas}

# %%
matrices_imports_i_k, matrices_self_i_k, total_imports_i_k, total_self_i_k = process_imports_and_self(results_imports_i_K, results_self_i_K, "ismr","BA","K")
matrices_imports_i_l, matrices_self_i_l, total_imports_i_l, total_self_i_l = process_imports_and_self(results_imports_i_L, results_self_i_L, "ismr","BA","L")
matrices_imports_a_k, matrices_self_a_k, total_imports_a_k, total_self_a_k = process_imports_and_self(results_imports_a_K, results_self_a_K, "aspca_q0","BA","K")
matrices_imports_a_l, matrices_self_a_l, total_imports_a_l, total_self_a_l = process_imports_and_self(results_imports_a_L, results_self_a_L, "apsca_q0","BA","L")


matrices_imports_i_k_gas, matrices_self_i_k_gas, total_imports_i_k_gas, total_self_i_k_gas = process_imports_and_self(results_imports_i_K_gas, results_self_i_K_gas, "ismr","BA","K")
matrices_imports_i_l_gas, matrices_self_i_l_gas, total_imports_i_l_gas, total_self_i_l_gas = process_imports_and_self(results_imports_i_L_gas, results_self_i_L_gas, "ismr","BA","L")
matrices_imports_a_k_gas, matrices_self_a_k_gas, total_imports_a_k_gas, total_self_a_k_gas = process_imports_and_self(results_imports_a_K_gas, results_self_a_K_gas, "apsca_q0","BA","K")
matrices_imports_a_l_gas, matrices_self_a_l_gas, total_imports_a_l_gas, total_self_a_l_gas = process_imports_and_self(results_imports_a_L_gas, results_self_a_L_gas, "apsca_q0","BA","L")
# Out:
# 15.103814424400706
# 5.953948625578596
# 5.235721341356294
# 3.6564018055502596
# 14.841265032929893
# 11.681317987877843
# 1.54990374944728
# 0.17744459383187444
# 0.21119089222535117
# 57.46718395721839
# 0.9528649284959495
# 9.547938971425774
# 14.660785588112848
# 6.2643134337648165
# 8.772819296813127
# 6.035545512735272
# 0.8137860939734438
# 6.457034324815263
# 0.022801174008092537
# 6.025498337205762
# 1.198639653629248
# 0.11520776541761114
# 0.9695564639334688
# 0.041149938839684354
# 1.8545480418532705
# 0.031007407290335492
# 8.420303933162781
# 11.182732191635308
# 1.300233674609875
# 0.7434044901091256
# 6.024853346022299
# 4.773234830694974
# 0.9706347297612339
# 3.8928959278416495
# 6.873742594025685
# 2.1495224091297693
# 3.603305639008979
# 55.403557281416006
# 3.137021624624598e-05
# 0.001733227179357818
# 11.217994540829611
# 1.912682635511572
# 5.899947111670971
# 15.706567591564832
# 0.9949278668258605
# 0.766677450661631
# 4.720682181349373
# ...

# %%
with open("total_imports_i_k",'wb') as f:
    pickle.dump(total_imports_i_k, f)
with open("total_self_i_k",'wb') as f:
    pickle.dump(total_self, f)
with open("matrices_self",'wb') as f:
    pickle.dump(matrices_self, f)
with open("matrices_imports9",'wb') as f:
    pickle.dump(matrices_imports, f)

# %%
matrices_self_i_k["total_deaths"].sum().sum()
# Out:
# 3749.351427328684

# %%
##### BASE SCENARIO
BAs_sorted = sort_BAs()
#results_imports, results_self, errors_imports, errors_self = run_imports_and_self(BAs_sorted["BACODE"], "isrm","all","L", True, True, False, False, False, results_imports_coal, results_self_coal)
results_imports_i, results_self_i, errors_imports_i, errors_self_i = run_imports_and_self(BAs_sorted["BACODE"], "isrm","all","LK", True, True, False, False, False, results_imports_i, results_self_i)
results_imports_i_K = {ba: results_imports_i[ba][0] for ba in results_imports_i}
results_imports_i_L = {ba: results_imports_i[ba][1] for ba in results_imports_i}
results_self_i_K = {ba: results_self_i[ba][0] for ba in results_self_i}
results_self_i_L = {ba: results_self_i[ba][1] for ba in results_self_i}
# Out:
# HECOCEA
# CEA import isrm
# HECO importall LK
#  AMPLisrm all LK
#
# AMPL import isrm all LK
# GRIS
# GRIS import isrm all LK
# HECO
# HECO self isrm all LK
# CEA
# CEA AMPL
# selfAMPL self isrm all LK
#  SCL
# SCL self isrm all LK
# TPWRCHPD
# TPWR self
# CHPD self isrm all LK
# isrmDOPDGCPDisrm all LK
#
#
# DOPD self isrm all LK
# GCPD self isrm  all LK
# all LK
# BPAT
# BPAT self isrm all LK
# /Users/Hennessy/Desktop/IMSR/Electricity_Imports_Analysis.py:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_export[E_export<0]=0
# /Users/Hennessy/Desktop/IMSR/Electricity_Imports_Analysis.py:255: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# import pickle
# with open("results_self_base_i_k",'wb') as f:
#     pickle.dump(results_self_i_K, f)
# with open("results_imports_base_i_k",'wb') as f:
#     pickle.dump(results_imports_i_K, f)
# with open("results_self_base_i_l",'wb') as f:
#     pickle.dump(results_self_i_L, f)
# with open("results_imports_base_i_l",'wb') as f:
#     pickle.dump(results_imports_i_L, f)

# %%
BAs_sorted = sort_BAs()
results_imports_a, results_self_a, errors_imports_a, errors_self_a = run_imports_and_self(BAs_sorted["BACODE"], "apsca_q0","all","LK", True, True, False, False, False, results_imports_a, results_self_a)
results_imports_a_K = {ba: results_imports_a[ba][0] for ba in results_imports_a}
results_imports_a_L = {ba: results_imports_a[ba][1] for ba in results_imports_a}
results_self_a_K = {ba: results_self_a[ba][0] for ba in results_self_a}
results_self_a_L = {ba: results_self_a[ba][1] for ba in results_self_a}
# Out:
# HECO
# HECO importCEA
# CEA import apsca_q0 apsca_q0 all LK
#  all LK
# AMPL
# AMPL import apsca_q0 all LK
# GRIS
# GRIS import apsca_q0 all LK
# HECO
# HECO self apsca_q0 all LK
# CEA
# CEA self apsca_q0 all LK
# AMPL
# AMPL self apsca_q0 all LK
# SCL
# SCL self apsca_q0 all LK
# TPWR
# TPWR self apsca_q0 all LKCHPD
# DOPD
# DOPD self GCPD
#
# HGMA
# HGMA apsca_q0 self apsca_q0all LK
# GCPD self apsca_q0 all LK
# CHPD all LK
#  self apsca_q0 all LK
# /Users/Hennessy/Desktop/IMSR/Electricity_Imports_Analysis.py:250: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   E_export[E_export<0]=0
# /Users/Hennessy/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3515: SettingWithCopyWarning:
# ...

# %%
##### NO GAS SCENARIO
BAs_sorted = sort_BAs()
#results_imports, results_self, errors_imports, errors_self = run_imports_and_self(BAs_sorted["BACODE"], "isrm","all","L", True, True, False, False, False, results_imports_coal, results_self_coal)
results_imports_i_gas, results_self_i_gas, errors_imports_i_gas, errors_self_i_gas = run_imports_and_self(BAs_sorted["BACODE"], "isrm","all","LK", True, False, False, False, False, results_imports_i_gas, results_self_i_gas)
results_imports_i_K_gas = {ba: results_imports_i_gas[ba][0] for ba in results_imports_i_gas}
results_imports_i_L_gas = {ba: results_imports_i_gas[ba][1] for ba in results_imports_i_gas}
results_self_i_K_gas = {ba: results_self_i_gas[ba][0] for ba in results_self_i_gas}
results_self_i_L_gas = {ba: results_self_i_gas[ba][1] for ba in results_self_i_gas}

results_imports_a_gas, results_self_a_gas, errors_imports_a_gas, errors_self_a_gas = run_imports_and_self(BAs_sorted["BACODE"], "apsca_q0","all","LK", True, False, False, False, False, results_imports_a_gas, results_self_a_gas)
results_imports_a_K_gas = {ba: results_imports_a_gas[ba][0] for ba in results_imports_a_gas}
results_imports_a_L_gas = {ba: results_imports_a_gas[ba][1] for ba in results_imports_a_gas}
results_self_a_K_gas = {ba: results_self_a_gas[ba][0] for ba in results_self_a_gas}
results_self_a_L_gas = {ba: results_self_a_gas[ba][1] for ba in results_self_a_gas}
# Out:
# HECO
# CEA
# HECO import isrm CEA importall LK
#  isrm allAMPL
# AMPL import isrm LK
#  all LK
# GRIS
# GRIS import isrm all LK
# HECO
# HECO self isrm all LK
# CEA
# CEA self isrm AMPL
# all LK
# AMPL self isrm all LK
# SCL
# SCL selfTPWR
# TPWR self isrm all PSEI
# PSEI self isrm all LK
# PACW
# PACW self LK
#  isrm all LK
# isrm all LK
# TIDC
# TIDC self isrm CHPD
# CHPD self isrm all LK
# all LK
# got geometrygot geometry
#
# isrm
# DOPD
# isrm
# GCPD
# GCPD self isrm all LK
# DOPD self isrm all LK
# got geometry
# isrm
# IPCO
# IPCO self isrm all LK
# got geometry
# got geometry
# isrm
# IID
# IID self isrm all LK
# isrm
# GRIF
# GRIF self isrm all LK
# got geometry
# isrm
# HGMA
# HGMA self isrm all LK
# got geometry
# got geometryisrm
# DEAA
# DEAA self isrm
#  all LK
# isrm
# GRMA
# GRMA self isrm all LK
# got geometry
# isrm
# GWA
# GWA self isrm all LK
# got geometry
# isrm
# WWA
# WWA self isrm all LK
# got geometry
# got geometry
# isrm
# WAUW
# isrm
# WAUWEPE
# ...
